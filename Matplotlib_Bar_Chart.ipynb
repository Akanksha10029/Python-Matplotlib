# %% [markdown]
# <a href="https://colab.research.google.com/github/Akanksha10029/Python-Matplotlib/blob/main/Matplotlib_Bar_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Matplotlib: Bar Chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Simple bar chart showing revenues of major US tech companies**

# %%
company=['GOOGL','AMZN','MSFT','FB']
revenue=[90,136,89,27]

# %%
'''.arange() generates a sequence of values from start to stop with a given step size,i.e, here size is 4(0,1,2,3) and it gives an array'''
xpos=np.arange(len(company)) # xpos= x-position
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue,label="Revenue")
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()

# %%
plt.bar(xpos,revenue,label="Revenue")
plt.xticks(xpos,company) #by using xticks it relaced the xpos with company names,i.e,array([0, 1, 2, 3]) 0=GOOGL, 1=AMZN, 2=MSFT and 3=FB
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()

# %% [markdown]
# **Multiple Bars showing revenue and profit of major US tech companies**

# %%
profit=[40,2,34,12]

# %%
plt.bar(xpos-0.2, revenue,width=0.4,label="Revenue")
plt.bar(xpos+0.2,profit,width=0.4,label="Profit")
plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technology Stocks')
plt.legend()

# %% [markdown]
# **Horizontal bar chart using barh function**

# %%
plt.barh(xpos,revenue, label="Revenue")

plt.yticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('US Technolog Stocks')
plt.legend()
